# %% [markdown]
# # How to use the API
#
# first run the ./src/api/main.py in a separate comand line
#
# then you can run the codes below.

# %%
import requests
import json

# %%
BASE_URL = "http://localhost:8000"

# %%
print("1. Health Check")
response = requests.get(f"{BASE_URL}/health")
print(json.dumps(response.json(), indent=2))
print("\n" + "="*80 + "\n")
# Out:
# 1. Health Check
# {
#   "status": "degraded",
#   "model_loaded": false,
#   "agents_initialized": true,
#   "timestamp": "2025-12-13T11:42:15.621970",
#   "version": "1.0.0"
# }
#
# ================================================================================

# %% [markdown]
# ## Single product prediction

# %%
print("2. Single Product Prediction")
product_data = {
    "product_id": "PROD_001",
    "price": 99.99,
    "rating": 4.5,
    "num_reviews": 150,
    "stock_quantity": 50,
    "sales_last_30d": 25,
    "views_last_30d": 500,
    "category": "Electronics",
    "brand": "TechBrand",
    "days_since_launch": 180,
    "discount_percentage": 10.0,
    "return_rate": 0.05
}

response = requests.post(f"{BASE_URL}/predict", json=product_data)
print(json.dumps(response.json(), indent=2))
print("\n" + "="*80 + "\n")
# Out:
# 2. Single Product Prediction
# {
#   "product_id": "PROD_001",
#   "prediction": "MANTER",
#   "confidence": 0.7287086524586521,
#   "probabilities": {
#     "DESCONTINUAR": 0.07400979575979577,
#     "MANTER": 0.7287086524586521,
#     "PROMOVER": 0.19728155178155177
#   },
#   "timestamp": "2025-12-13T11:45:15.613156"
# }
#
# ================================================================================

# %%
print("3. Batch Prediction")
batch_data = {
    "products": [
        product_data,
        {
            "product_id": "PROD_002",
            "price": 29.99,
            "rating": 3.8,
            "num_reviews": 50,
            "stock_quantity": 200,
            "sales_last_30d": 100,
            "views_last_30d": 2000,
            "category": "Home",
            "brand": "HomeBrand",
            "days_since_launch": 90,
            "discount_percentage": 20.0,
            "return_rate": 0.08
        }
    ]
}

response = requests.post(f"{BASE_URL}/predict/batch", json=batch_data)
print(json.dumps(response.json(), indent=2))
print("\n" + "="*80 + "\n")
# Out:
# 3. Batch Prediction
# {
#   "predictions": [
#     {
#       "product_id": "PROD_001",
#       "prediction": "MANTER",
#       "confidence": 0.7287086524586521,
#       "probabilities": {
#         "DESCONTINUAR": 0.07400979575979577,
#         "MANTER": 0.7287086524586521,
#         "PROMOVER": 0.19728155178155177
#       },
#       "timestamp": "2025-12-13T11:46:02.985085"
#     },
#     {
#       "product_id": "PROD_002",
#       "prediction": "MANTER",
#       "confidence": 0.9285873015873016,
#       "probabilities": {
#         "DESCONTINUAR": 0.01837301587301587,
#         "MANTER": 0.9285873015873016,
#         "PROMOVER": 0.053039682539682546
#       },
#       "timestamp": "2025-12-13T11:46:02.985123"
#     }
#   ],
#   "total_products": 2,
#   "timestamp": "2025-12-13T11:46:02.985130"
# }
#
# ================================================================================

# %%
print("4. Multi-Agent Analysis")
analysis_request = {
    "products": [product_data],
    "analysis_type": "complete",
    "include_recommendations": True
}

response = requests.post(f"{BASE_URL}/analyze", json=analysis_request)
print(json.dumps(response.json(), indent=2))
# Out:
# 4. Multi-Agent Analysis
# {
#   "analysis_id": "ANALYSIS_20251213_122444",
#   "timestamp": "2025-12-13T12:24:44.852722",
#   "products_analyzed": 1,
#   "analyst_insights": {
#     "agent": "Analyst Agent",
#     "version": "1.0.0",
#     "timestamp": "2025-12-13T12:24:44.851922",
#     "products_analyzed": 1,
#     "predictions": [
#       {
#         "product_id": "PROD_001",
#         "price": 99.99,
#         "rating": 4.5,
#         "num_reviews": 150,
#         "stock_quantity": 50,
#         "sales_last_30d": 25,
#         "views_last_30d": 500,
#         "category": "Electronics",
#         "brand": "TechBrand",
#         "days_since_launch": 180,
#         "discount_percentage": 10.0,
#         "return_rate": 0.05,
#         "conversion_rate": null,
#         "launch_date": null,
#         "last_updated": null,
#         "prediction": 1,
#         "prediction_label": "MANTER",
#         "confidence": 0.7287086524586521,
#         "prob_descontinuar": 0.07400979575979577,
#         "prob_manter": 0.7287086524586521,
#         "prob_promover": 0.19728155178155177
#       }
#     ],
#     "insights": [
#       {
#         "type": "MAINTAIN",
#         "title": "Produtos Est\u00e1veis",
#         "description": "1 produtos com desempenho est\u00e1vel",
#         "count": 1,
#         "recommendation": "Manter estrat\u00e9gia atual e monitorar performance"
#       },
#       {
#         "type": "CATEGORY",
#         "title": "An\u00e1lise por Categoria",
#         "description": "Categoria com melhor desempenho: Electronics",
#         "best_category": "Electronics",
#         "total_sales": 25.0,
#         "all_categories": {
#           "Electronics": {
#             "avg_confidence": 0.7287086524586521,
#             "total_sales": 25.0
#           }
#         }
#       }
#     ],
#     "statistics": {
#       "total_products": 1,
#       "predictions_distribution": {
#         "MANTER": 1
#       },
#       "confidence_metrics": {
#         "mean": 0.7287086524586521,
#         "median": 0.7287086524586521,
#         "min": 0.7287086524586521,
#         "max": 0.7287086524586521,
#         "std": null
#       },
#       "business_metrics": {
#         "total_revenue_last_30d": 2499.75,
#         "average_rating": 4.5,
#         "total_sales_last_30d": 25,
#         "total_stock_value": 4999.5,
#         "products_out_of_stock": 0
#       },
#       "category_breakdown": {
#         "Electronics": 1
#       }
#     },
#     "execution_time": 0.042695045471191406,
#     "agent_metrics": {
#       "total_analyses": 1,
#       "total_products_analyzed": 1,
#       "average_confidence": 0.7287086524586521,
#       "performance": {
#         "avg_execution_time": 0.042695045471191406,
#         "min_execution_time": 0.042695045471191406,
#         "max_execution_time": 0.042695045471191406
#       }
#     }
#   },
#   "strategist_recommendations": {
#     "strategic_priorities": [],
#     "action_plans": [
#       {
#         "action": 1,
#         "products_count": 1,
#         "steps": [],
#         "estimated_duration": "Unknown",
#         "required_resources": []
#       }
#     ],
#     "risk_mitigation": [
#       {
#         "risk": "Low Customer Satisfaction",
#         "severity": "MEDIUM",
#         "description": "Average rating of 0.0 may hurt sales",
#         "mitigation": "Improve product quality and customer service"
#       },
#       {
#         "risk": "Stock Shortage",
#         "severity": "MEDIUM",
#         "description": "Low stock levels may lead to stockouts",
#         "mitigation": "Increase safety stock and improve forecasting"
#       }
#     ],
#     "expected_impact": {
#       "estimated_revenue_increase": 0.0,
#       "estimated_cost_savings": 0.0,
#       "total_estimated_impact": 0.0,
#       "confidence_level": "MEDIUM",
#       "timeframe": "3-6 months"
#     },
#     "timeline": {
#       "immediate (0-2 weeks)": [
#         "Analyze detailed product performance data",
#         "Identify quick wins for promotion",
#         "Start discontinuation process for worst performers"
#       ],
#       "short_term (2-8 weeks)": [
#         "Launch promotional campaigns",
#         "Complete product discontinuations",
#         "Optimize inventory levels"
#       ],
#       "medium_term (2-6 months)": [
#         "Monitor impact of changes",
#         "Adjust strategies based on results",
#         "Scale successful initiatives"
#       ]
#     },
#     "resource_allocation": {
#       "marketing_budget": {
#         "recommendation": "Increase by 0%",
#         "allocation": "Focus on products marked for promotion"
#       },
#       "inventory_investment": {
#         "recommendation": "Increase for high-potential products",
#         "allocation": "Reduce for products to discontinue"
#       },
#       "team_focus": {
#         "recommendation": "Prioritize high-impact actions",
#         "allocation": "Assign dedicated resources to promotional campaigns"
#       }
#     }
#   },
#   "executive_summary": {
#     "title": "An\u00e1lise de Ciclo de Vida de Produtos - NexoCommerce",
#     "period": "\u00daltimos 30 dias",
#     "total_products_analyzed": 1,
#     "analysis_date": "13/12/2025",
#     "key_findings": [
#       "1 produtos com desempenho est\u00e1vel",
#       "Confian\u00e7a m\u00e9dia das predi\u00e7\u00f5es: 72.87%"
#     ],
#     "priority_actions": 0,
#     "overall_health": "\ud83d\udfe1 MODERADO - Oportunidades de otimiza\u00e7\u00e3o",
#     "estimated_revenue_impact": "R$ 0.00",
#     "confidence_level": "72.9%",
#     "next_steps": "Revisar recomenda\u00e7\u00f5es priorit\u00e1rias e implementar plano de a\u00e7\u00e3o"
#   },
#   "status": "completed"
# }
